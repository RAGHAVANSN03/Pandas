# %%
# String Methods

# %%
import pandas as pd
orders = pd.read_table('http://bit.ly/chiporders')
orders
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
orders.item_name.str.upper()
# Out:
# 0                CHIPS AND FRESH TOMATO SALSA
# 1                                        IZZE
# 2                            NANTUCKET NECTAR
# 3       CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                                CHICKEN BOWL
#                         ...
# 4617                            STEAK BURRITO
# 4618                            STEAK BURRITO
# 4619                       CHICKEN SALAD BOWL
# 4620                       CHICKEN SALAD BOWL
# 4621                       CHICKEN SALAD BOWL
# Name: item_name, Length: 4622, dtype: object

# %%
orders.item_name.str.lower()
# Out:
# 0                chips and fresh tomato salsa
# 1                                        izze
# 2                            nantucket nectar
# 3       chips and tomatillo-green chili salsa
# 4                                chicken bowl
#                         ...
# 4617                            steak burrito
# 4618                            steak burrito
# 4619                       chicken salad bowl
# 4620                       chicken salad bowl
# 4621                       chicken salad bowl
# Name: item_name, Length: 4622, dtype: object

# %%
# how to add column to existing data frame
orders['item_len']=orders.item_name.str.len()

# %%
orders
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price  item_len
# 0                                                   NaN     $2.39         28
# ...

# %%
orders['item_second']=orders.item_name.str.split('and')

# %%
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  item_len  \
# 0                                                NaN     $2.39         28
# 1                                       [Clementine]     $3.39          4
# 2                                            [Apple]     $3.39         16
# 3                                                NaN     $2.39         37
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98         12
#
#                               item_second
# 0           [Chips ,  Fresh Tomato Salsa]
# 1                                  [Izze]
# ...

# %%
orders['item_second'].loc[0][1]
# Out:
# ' Fresh Tomato Salsa'

# %%
orders.item_name.str.contains('Chicken')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 4617    False
# 4618    False
# 4619     True
# 4620     True
# 4621     True
# Name: item_name, Length: 4622, dtype: bool

# %%
nv=orders[orders.item_name.str.contains('Chicken')]

# %%
nv
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 5            3         1          Chicken Bowl
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 13           7         1          Chicken Bowl
# ...        ...       ...                   ...
# 4604      1828         1          Chicken Bowl
# 4615      1832         1    Chicken Soft Tacos
# 4619      1834         1    Chicken Salad Bowl
# 4620      1834         1    Chicken Salad Bowl
# 4621      1834         1    Chicken Salad Bowl
#
#                                      choice_description item_price  item_len
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98         12
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98         12
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75         20
# 12    [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75         18
# ...

# %%
df
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 5            3         1          Chicken Bowl
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 13           7         1          Chicken Bowl
# ...        ...       ...                   ...
# 4604      1828         1          Chicken Bowl
# 4615      1832         1    Chicken Soft Tacos
# 4619      1834         1    Chicken Salad Bowl
# 4620      1834         1    Chicken Salad Bowl
# 4621      1834         1    Chicken Salad Bowl
#
#                                      choice_description item_price  item_len  \
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98         12
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98         12
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75         20
# 12    [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75         18
# ...

# %%
# string methods can be chained together
orders.choice_description.str.replace('[', '').str.replace(']', '').head()
# Out:
# C:\Users\Rajesh\AppData\Local\Temp/ipykernel_7200/7676934.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   orders.choice_description.str.replace('[', '').str.replace(']', '').head()
# 0                                                  NaN
# 1                                           Clementine
# 2                                                Apple
# 3                                                  NaN
# 4    Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
# Name: choice_description, dtype: object

# %%
filt = orders['item_name'].str.contains('Chicken', na=False)

# %%
filt
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 4617    False
# 4618    False
# 4619     True
# 4620     True
# 4621     True
# Name: item_name, Length: 4622, dtype: bool

# %%
orders.loc[filt]
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 5            3         1          Chicken Bowl
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# 13           7         1          Chicken Bowl
# ...        ...       ...                   ...
# 4604      1828         1          Chicken Bowl
# 4615      1832         1    Chicken Soft Tacos
# 4619      1834         1    Chicken Salad Bowl
# 4620      1834         1    Chicken Salad Bowl
# 4621      1834         1    Chicken Salad Bowl
#
#                                      choice_description item_price  item_len  \
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98         12
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98         12
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75         20
# 12    [Roasted Chili Corn Salsa, [Rice, Black Beans,...     $8.75         18
# ...

# %%
orders.choice_description.str.split(',').head()
# Out:
# 0                                                  NaN
# 1                                       [[Clementine]]
# 2                                            [[Apple]]
# 3                                                  NaN
# 4    [[Tomatillo-Red Chili Salsa (Hot),  [Black Bea...
# Name: choice_description, dtype: object

# %%
orders['item_name_sec']=orders['item_name'].str.split('and')

# %%
orders.head(20)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
orders['item_name_sec'][0]
# Out:
# ['Chips ', ' Fresh Tomato Salsa']
